# %%
#1.
import pandas as pd
from sklearn.feature_selection import SelectKBest, f_classif

df = pd.DataFrame({
    'age': [20, 30, None],
    'income': [40000, 50000, 60000],
    'target': [1, 0, 1]
})

X = df[['age', 'income']]
y = df['target']

selector = SelectKBest(f_classif, k=1)
X_new = selector.fit_transform(X, y)
print("Shape:", X_new.shape)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 15
#      12 y = df['target']
#      14 selector = SelectKBest(f_classif, k=1)
# ---> 15 X_new = selector.fit_transform(X, y)
#      16 print("Shape:", X_new.shape)
#
# File ~/Documents/anaconda3/envs/myenv/lib/python3.11/site-packages/sklearn/utils/_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# ...

# %%
#ans- SelectKBest does not support missing values (NaN).we use .fillna(mean) to impute missing values.

import pandas as pd
from sklearn.feature_selection import SelectKBest, f_classif

df = pd.DataFrame({
    'age': [20, 30, None],
    'income': [40000, 50000, 60000],
    'target': [1, 0, 1]
})

X = df[['age', 'income']].fillna(df[['age', 'income']].mean())
y = df['target']

selector = SelectKBest(f_classif, k=1)
X_new = selector.fit_transform(X, y)
print("Shape:", X_new.shape)
# Out:
# Shape: (3, 1)

# %%
#2.
from sklearn.model_selection import GridSearchCV
grid = GridSearchCV(model, param_grid, scoring='accuracy_score')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 #2.
#       2 from sklearn.model_selection import GridSearchCV
# ----> 3 grid = GridSearchCV(model, param_grid, scoring='accuracy_score')
#
# NameError: name 'model' is not defined

# %%
#ans-Scoring in GridSearchCV must be a valid scorer string like 'accuracy', not 'accuracy_score'.

from sklearn.model_selection import GridSearchCV
grid = GridSearchCV(model, param_grid, scoring='accuracy')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 4
#       1 #ans-Scoring in GridSearchCV must be a valid scorer string like 'accuracy', not 'accuracy_score'.
#       3 from sklearn.model_selection import GridSearchCV
# ----> 4 grid = GridSearchCV(model, param_grid, scoring='accuracy')
#
# NameError: name 'model' is not defined

# %%
#3.
from sklearn.decomposition import PCA
from sklearn.datasets import load_wine
import pandas as pd

data = load_wine()
X = pd.DataFrame(data.data, columns=data.feature_names)

pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)
print("PCA shape:", X_pca.shape)
# Out:
# PCA shape: (178, 2)

# %%
#ans-PCA is sensitive to feature scaling. Without normalization, PCA gives distorted results.

from sklearn.decomposition import PCA
from sklearn.datasets import load_wine
from sklearn.preprocessing import StandardScaler
import pandas as pd

data = load_wine()
X = pd.DataFrame(data.data, columns=data.feature_names)

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)
print("PCA shape:", X_pca.shape)
# Out:
# PCA shape: (178, 2)

# %%
#4.
from sklearn.feature_selection import VarianceThreshold
selector = VarianceThreshold(threshold=1.0)
X_new = selector.fit_transform(X)

# %%
#ans-A high threshold (1.0) removes all features unless variance > 1. Use smaller threshold.
selector = VarianceThreshold(threshold=0.1)
X_new = selector.fit_transform(X)

# %%
#5.
from sklearn.feature_selection import SelectKBest, f_classif
skb = SelectKBest(f_classif, k=5)
X_new = skb.fit_transform(X, y_regression)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 4
#       2 from sklearn.feature_selection import SelectKBest, f_classif
#       3 skb = SelectKBest(f_classif, k=5)
# ----> 4 X_new = skb.fit_transform(X, y_regression)
#
# NameError: name 'y_regression' is not defined

# %%
#ans-Use f_regression for continuous targets, f_classif for classification.
from sklearn.feature_selection import f_regression
skb = SelectKBest(f_regression, k=5)
X_new = skb.fit_transform(X, y_regression)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 4
#       2 from sklearn.feature_selection import f_regression
#       3 skb = SelectKBest(f_regression, k=5)
# ----> 4 X_new = skb.fit_transform(X, y_regression)
#
# NameError: name 'y_regression' is not defined

# %%
#6.
from sklearn.feature_selection import RFECV
rfecv = RFECV(LogisticRegression())
rfecv.fit_transform(X, y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 3
#       1 #6.
#       2 from sklearn.feature_selection import RFECV
# ----> 3 rfecv = RFECV(LogisticRegression())
#       4 rfecv.fit_transform(X, y)
#
# NameError: name 'LogisticRegression' is not defined

# %%
#ans-
from sklearn.feature_selection import RFECV
rfecv = RFECV(estimator=LogisticRegression(), step=1, cv=5, scoring='accuracy')
X_selected = rfecv.fit_transform(X, y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 3
#       1 #ans-
#       2 from sklearn.feature_selection import RFECV
# ----> 3 rfecv = RFECV(estimator=LogisticRegression(), step=1, cv=5, scoring='accuracy')
#       4 X_selected = rfecv.fit_transform(X, y)
#
# NameError: name 'LogisticRegression' is not defined

# %%
#7.
model = SelectFromModel(LinearRegression(), threshold='0.25')
model.fit(X, y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 #7.
# ----> 2 model = SelectFromModel(LinearRegression(), threshold='0.25')
#       3 model.fit(X, y)
#
# NameError: name 'SelectFromModel' is not defined

# %%
#ans-Strings like '0.25' are invalid unless it's 'mean' or 'median'. Use float for numeric thresholds.
model = SelectFromModel(LinearRegression(), threshold=0.25)
model.fit(X, y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 #ans-Strings like '0.25' are invalid unless it's 'mean' or 'median'. Use float for numeric thresholds.
# ----> 2 model = SelectFromModel(LinearRegression(), threshold=0.25)
#       3 model.fit(X, y)
#
# NameError: name 'SelectFromModel' is not defined

# %%
#8.
selector = VarianceThreshold(value=0.1)
X_new = selector.fit_transform(X)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 #8.
# ----> 2 selector = VarianceThreshold(value=0.1)
#       3 X_new = selector.fit_transform(X)
#
# TypeError: VarianceThreshold.__init__() got an unexpected keyword argument 'value'

# %%
#ans-The correct keyword is threshold, not value.

from sklearn.feature_selection import VarianceThreshold
selector = VarianceThreshold(threshold=0.1)
X_new = selector.fit_transform(X)

# %%
#9.
from sklearn.datasets import load_iris
from sklearn.feature_selection import SelectKBest, f_classif
import pandas as pd

data = load_iris()
X = pd.DataFrame(data.data, columns=data.feature_names)
selector = SelectKBest(score_func=f_classif, k=2)
X_new = selector.fit_transform(X)
print("Selected Features Shape:", X_new.shape)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 9
#       7 X = pd.DataFrame(data.data, columns=data.feature_names)
#       8 selector = SelectKBest(score_func=f_classif, k=2)
# ----> 9 X_new = selector.fit_transform(X)
#      10 print("Selected Features Shape:", X_new.shape)
#
# File ~/Documents/anaconda3/envs/myenv/lib/python3.11/site-packages/sklearn/utils/_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
# ...

# %%
#ans-SelectKBest requires both features (X) and target (y). The buggy code skipped y, leading to an error.
from sklearn.datasets import load_iris
from sklearn.feature_selection import SelectKBest, f_classif
import pandas as pd

data = load_iris()
X = pd.DataFrame(data.data, columns=data.feature_names)
y = data.target

selector = SelectKBest(score_func=f_classif, k=2)
X_new = selector.fit_transform(X, y)
print("Selected Features Shape:", X_new.shape)
# Out:
# Selected Features Shape: (150, 2)

# %%
#10.
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import load_breast_cancer
import pandas as pd

data = load_breast_cancer()
X = pd.DataFrame(data.data, columns=data.feature_names)
y = data.target

selector = SelectFromModel(LogisticRegression())
X_new = selector.transform(X)
print(X_new.shape)
# Out:
# /Users/harikrishnan/Documents/anaconda3/envs/myenv/lib/python3.11/site-packages/sklearn/utils/validation.py:2742: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 12
#       9 y = data.target
#      11 selector = SelectFromModel(LogisticRegression())
# ---> 12 X_new = selector.transform(X)
#      13 print(X_new.shape)
#
# File ~/Documents/anaconda3/envs/myenv/lib/python3.11/site-packages/sklearn/utils/_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
# ...

# %%
#ans-SelectFromModel requires a fitted model before transformation. Fit it first using .fit(X, y)
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import load_breast_cancer
import pandas as pd

data = load_breast_cancer()
X = pd.DataFrame(data.data, columns=data.feature_names)
y = data.target

selector = SelectFromModel(LogisticRegression(max_iter=1000))
selector.fit(X, y)
X_new = selector.transform(X)
print(X_new.shape)
# Out:
# (569, 11)
# /Users/harikrishnan/Documents/anaconda3/envs/myenv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 1000 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=1000).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
